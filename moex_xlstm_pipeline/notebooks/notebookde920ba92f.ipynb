# %% [markdown]
# # xLSTM + Recurrent PPO: торговля на MOEX (Short стратегия)
#
# Все исправления учтены:
# - `n_steps=2048` (было 128)
# - `device=DEVICE` (было 'auto')
# - `check_slstm_available()` по Compute Capability
# - `.to(DEVICE)` на модели и тензорах
# - Short-среда с `margin_ratio=0.5`
# - Отдельные переменные `model_short`, `portfolio_hist_short`, `short_metrics`

# %%
# !pip install stable-baselines3 sb3-contrib pandas numpy requests apimoex matplotlib -q
# !pip install git+https://github.com/NX-AI/xlstm.git -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 4.9 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 8.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 9.7 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 46.7 MB/s eta 0:00:0000:01
#   Building wheel for xlstm (pyproject.toml) ... done

# %%
import pandas as pd
import numpy as np
import requests
import apimoex
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Шаг 1: Загрузка данных

# %%
TICKERS     = ['SBER', 'GAZP', 'LKOH', 'YNDX', 'GMKN']
TRAIN_START = '2009-01-01'
TRAIN_END   = '2021-12-31'
TEST_START  = '2022-01-01'
TEST_END    = '2024-01-01'
DATA_FILE   = 'moex_data.csv'


def download_moex_ohlcv(ticker, start, end):
    with requests.Session() as session:
        data = apimoex.get_board_history(
            session, ticker, start=start, end=end,
            columns=('TRADEDATE', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'VOLUME'))
    if not data:
        raise ValueError(f'Нет данных для {ticker}')
    df = pd.DataFrame(data)
    df['TRADEDATE'] = pd.to_datetime(df['TRADEDATE'])
    df = df.set_index('TRADEDATE')
    df.columns = [c.lower() for c in df.columns]
    df = df.add_prefix(f'{ticker}_')
    return df.replace(0, np.nan)


def load_or_download(tickers, start, end, cache_file):
    import os
    if os.path.exists(cache_file):
        print(f'Загружаем из кэша: {cache_file}')
        return pd.read_csv(cache_file, index_col=0, parse_dates=True)
    print('Скачиваем данные с MOEX ISS...')
    frames = []
    for t in tickers:
        print(f'  {t}...', end=' ', flush=True)
        frames.append(download_moex_ohlcv(t, start, end))
        print('OK')
    df = pd.concat(frames, axis=1).ffill().bfill()
    df.to_csv(cache_file)
    return df


raw = load_or_download(TICKERS, TRAIN_START, TEST_END, DATA_FILE)
print(f'Загружено: {raw.shape[0]} дней, {raw.shape[1]} колонок')
# Out:
# Скачиваем данные с MOEX ISS...
#   SBER... OK
#   GAZP... OK
#   LKOH... OK
#   YNDX... OK
#   GMKN... OK
# Загружено: 2718 дней, 25 колонок

# %% [markdown]
# ## Шаг 2: Features + Turbulence

# %%
def extract_close_prices(df, tickers):
    return df[[f'{t}_close' for t in tickers]].copy()


def compute_turbulence(close_prices, lookback=252):
    returns    = close_prices.pct_change().dropna()
    turbulence = pd.Series(index=returns.index, dtype=float, name='turbulence')
    for i in range(lookback, len(returns)):
        hist = returns.iloc[i - lookback:i]
        y    = returns.iloc[i].values - hist.mean().values
        try:
            turb = float(y @ np.linalg.pinv(hist.cov().values) @ y)
        except Exception:
            turb = 0.0
        turbulence.iloc[i] = max(turb, 0.0)
    return turbulence.fillna(0.0)


def compute_features(df, tickers):
    parts = []
    for t in tickers:
        sub = df[[f'{t}_{c}' for c in ['open', 'high', 'low', 'close', 'volume']]].copy()
        sub = (sub - sub.mean()) / (sub.std() + 1e-8)
        parts.append(sub.values)
    return np.concatenate(parts, axis=1).astype(np.float32)


close_prices = extract_close_prices(raw, TICKERS)

print('Считаем turbulence index (~1–2 мин)...')
turbulence = compute_turbulence(close_prices)

TURBULENCE_THRESHOLD = float(np.percentile(turbulence[TRAIN_START:TRAIN_END].dropna(), 75))
print(f'Turbulence threshold: {TURBULENCE_THRESHOLD:.2f}')

common_idx   = raw.index.intersection(turbulence.dropna().index)
raw_aligned  = raw.loc[common_idx]
turb_aligned = turbulence.loc[common_idx]
features_all = compute_features(raw_aligned, TICKERS)
close_all    = close_prices.loc[common_idx].values.astype(np.float32)
dates_all    = raw_aligned.index

train_mask = (dates_all >= TRAIN_START) & (dates_all <= TRAIN_END)
test_mask  = (dates_all >= TEST_START)  & (dates_all <= TEST_END)

features_train = features_all[train_mask]
close_train    = close_all[train_mask]
turb_train_arr = turb_aligned[train_mask].values
features_test  = features_all[test_mask]
close_test     = close_all[test_mask]
turb_test_arr  = turb_aligned[test_mask].values

print(f'Train: {features_train.shape[0]} дней | Test: {features_test.shape[0]} дней')
# Out:
# Считаем turbulence index (~1–2 мин)...
# Turbulence threshold: 6.05
# Train: 2211 дней | Test: 506 дней

# %% [markdown]
# ## Шаг 3: Торговые среды

# %%
import gymnasium as gym
from gymnasium import spaces


class MOEXTradingEnv(gym.Env):
    """Long-only среда (базовая)."""
    metadata = {'render_modes': []}

    def __init__(self, close_prices, features, turbulence, turbulence_threshold,
                 initial_balance=1_000_000.0, window_size=30,
                 commission=0.0005, max_shares_per_trade=100):
        super().__init__()
        self.close_prices         = close_prices
        self.features             = features
        self.turbulence           = turbulence
        self.turbulence_threshold = turbulence_threshold
        self.initial_balance      = initial_balance
        self.window_size          = window_size
        self.commission           = commission
        self.max_shares           = max_shares_per_trade
        self.n_assets             = close_prices.shape[1]
        self.n_features           = features.shape[1]
        self.action_space      = spaces.Box(low=-1.0, high=1.0, shape=(self.n_assets,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf,
                                            shape=(window_size, self.n_features), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step         = self.window_size
        self.balance              = self.initial_balance
        self.shares_held          = np.zeros(self.n_assets, dtype=np.float32)
        self.prev_portfolio_value = self.initial_balance
        self.portfolio_history    = [self.initial_balance]
        self.trade_count          = 0
        return self._get_obs(), {}

    def step(self, action):
        turb = self.turbulence[self.current_step]
        if turb > self.turbulence_threshold:
            self.current_step += 1
            done = self.current_step >= len(self.close_prices)
            self.portfolio_history.append(self._portfolio_value())
            return self._get_obs(), -1.0, done, False, {'turbulence': turb}

        prices       = self.close_prices[self.current_step]
        shares_delta = (action * self.max_shares).astype(np.float32)
        shares_delta = np.maximum(shares_delta, -self.shares_held)

        buy_cost = np.sum(np.maximum(shares_delta, 0) * prices)
        if buy_cost > self.balance:
            shares_delta = np.where(shares_delta > 0,
                                    shares_delta * self.balance / (buy_cost + 1e-8),
                                    shares_delta)

        cost             = np.sum(np.abs(shares_delta) * prices) * self.commission
        self.balance    -= np.sum(shares_delta * prices) + cost
        self.shares_held += shares_delta
        self.trade_count += int(np.any(shares_delta != 0))
        self.current_step += 1

        done      = self.current_step >= len(self.close_prices)
        new_value = self._portfolio_value()
        self.portfolio_history.append(new_value)
        reward    = float(np.clip((new_value - self.prev_portfolio_value) /
                                  (self.prev_portfolio_value + 1e-8), -1.0, 1.0))
        self.prev_portfolio_value = new_value
        return self._get_obs(), reward, done, False, {'portfolio_value': new_value, 'turbulence': turb}

    def render(self):
        v = self._portfolio_value()
        print(f'День {self.current_step:4d} | {v:>14,.0f} ₽ | {(v/self.initial_balance-1)*100:+.2f}%')

    def _get_obs(self):
        return self.features[self.current_step - self.window_size:self.current_step].copy()

    def _portfolio_value(self):
        idx = min(self.current_step, len(self.close_prices) - 1)
        return float(self.balance + np.sum(self.shares_held * self.close_prices[idx]))


class MOEXTradingEnvShort(MOEXTradingEnv):
    """
    Расширение с поддержкой short selling.
    action > 0 → покупка (long)
    action < 0 → продажа в шорт
    Максимальный шорт = margin_ratio * стоимость портфеля.
    """

    def __init__(self, *args, margin_ratio=0.5, **kwargs):
        super().__init__(*args, **kwargs)
        self.margin_ratio = margin_ratio

    def step(self, action):
        turb = self.turbulence[self.current_step]
        if turb > self.turbulence_threshold:
            self.current_step += 1
            done = self.current_step >= len(self.close_prices)
            self.portfolio_history.append(self._portfolio_value())
            return self._get_obs(), -1.0, done, False, {'turbulence': turb}

        prices           = self.close_prices[self.current_step]
        shares_delta     = (action * self.max_shares).astype(np.float32)
        max_short_value  = self._portfolio_value() * self.margin_ratio

        for i in range(self.n_assets):
            if shares_delta[i] < 0:
                max_short_shares = max_short_value / (prices[i] + 1e-8)
                shares_delta[i]  = max(shares_delta[i],
                                       -max_short_shares - self.shares_held[i])

        buy_cost = np.sum(np.maximum(shares_delta, 0) * prices)
        if buy_cost > self.balance:
            shares_delta = np.where(shares_delta > 0,
                                    shares_delta * self.balance / (buy_cost + 1e-8),
                                    shares_delta)

        cost             = np.sum(np.abs(shares_delta) * prices) * self.commission
        self.balance    -= np.sum(shares_delta * prices) + cost
        self.shares_held += shares_delta
        self.trade_count += int(np.any(shares_delta != 0))
        self.current_step += 1

        done      = self.current_step >= len(self.close_prices)
        new_value = self._portfolio_value()
        self.portfolio_history.append(new_value)
        reward    = float(np.clip((new_value - self.prev_portfolio_value) /
                                  (self.prev_portfolio_value + 1e-8), -1.0, 1.0))
        self.prev_portfolio_value = new_value
        return self._get_obs(), reward, done, False, {'portfolio_value': new_value, 'turbulence': turb}


# Создаём все окружения
WINDOW_SIZE = 30

env_train = MOEXTradingEnv(
    close_prices=close_train, features=features_train,
    turbulence=turb_train_arr, turbulence_threshold=TURBULENCE_THRESHOLD, window_size=WINDOW_SIZE)
env_test = MOEXTradingEnv(
    close_prices=close_test, features=features_test,
    turbulence=turb_test_arr, turbulence_threshold=TURBULENCE_THRESHOLD, window_size=WINDOW_SIZE)
env_train_short = MOEXTradingEnvShort(
    close_prices=close_train, features=features_train,
    turbulence=turb_train_arr, turbulence_threshold=TURBULENCE_THRESHOLD,
    window_size=WINDOW_SIZE, margin_ratio=0.5)
env_test_short = MOEXTradingEnvShort(
    close_prices=close_test, features=features_test,
    turbulence=turb_test_arr, turbulence_threshold=TURBULENCE_THRESHOLD,
    window_size=WINDOW_SIZE, margin_ratio=0.5)

print('Все среды созданы.')
print(f'Observation space: {env_train_short.observation_space.shape}')
print(f'Action space:      {env_train_short.action_space}  (< 0 = шорт)')
# Out:
# Все среды созданы.
# Observation space: (30, 25)
# Action space:      Box(-1.0, 1.0, (5,), float32)  (< 0 = шорт)

# %% [markdown]
# ## Шаг 4: xLSTM Encoder

# %%
import torch
import torch.nn as nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from sb3_contrib import RecurrentPPO
from xlstm import (
    xLSTMBlockStack, xLSTMBlockStackConfig,
    mLSTMBlockConfig, mLSTMLayerConfig,
    sLSTMBlockConfig, sLSTMLayerConfig, FeedForwardConfig,
)


def build_xlstm_stack(embedding_dim, context_length, num_blocks=4, use_slstm=False):
    if use_slstm:
        cfg = xLSTMBlockStackConfig(
            mlstm_block=mLSTMBlockConfig(
                mlstm=mLSTMLayerConfig(conv1d_kernel_size=4, qkv_proj_blocksize=4, num_heads=4)),
            slstm_block=sLSTMBlockConfig(
                slstm=sLSTMLayerConfig(backend='cuda', num_heads=4,
                                       conv1d_kernel_size=4, bias_init='powerlaw_blockdependent'),
                feedforward=FeedForwardConfig(proj_factor=1.3, act_fn='gelu')),
            context_length=context_length, num_blocks=num_blocks,
            embedding_dim=embedding_dim, slstm_at=[1])
    else:
        cfg = xLSTMBlockStackConfig(
            mlstm_block=mLSTMBlockConfig(
                mlstm=mLSTMLayerConfig(conv1d_kernel_size=4, qkv_proj_blocksize=4, num_heads=4)),
            context_length=context_length, num_blocks=num_blocks,
            embedding_dim=embedding_dim, slstm_at=[])
    return xLSTMBlockStack(cfg)


class xLSTMEncoder(BaseFeaturesExtractor):
    def __init__(self, observation_space, embedding_dim=128, num_blocks=4, use_slstm=False):
        super().__init__(observation_space, features_dim=embedding_dim)
        window_size, n_features = observation_space.shape
        self.input_proj = nn.Sequential(nn.Linear(n_features, embedding_dim), nn.GELU())
        self.xlstm = build_xlstm_stack(embedding_dim, window_size, num_blocks, use_slstm)

    def forward(self, observations):
        x = self.input_proj(observations)
        x = self.xlstm(x)
        return x[:, -1, :]


def check_slstm_available():
    if not torch.cuda.is_available():
        return False
    return torch.cuda.get_device_capability()[0] >= 8


DEVICE        = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
USE_SLSTM     = check_slstm_available()
EMBEDDING_DIM = 128

print(f'Device: {DEVICE}')
if torch.cuda.is_available():
    major, minor = torch.cuda.get_device_capability()
    print(f'Compute Capability: {major}.{minor} ({"sLSTM OK" if USE_SLSTM else "CC < 8.0 → mLSTM"})')
print(f'USE_SLSTM: {USE_SLSTM}')

# Проверка
test_enc  = xLSTMEncoder(env_train_short.observation_space, EMBEDDING_DIM, use_slstm=USE_SLSTM).to(DEVICE)
dummy_obs = torch.zeros(2, *env_train_short.observation_space.shape).to(DEVICE)
out       = test_enc(dummy_obs)
print(f'Encoder output: {out.shape}  (ожидается [2, {EMBEDDING_DIM}])')
del test_enc, dummy_obs, out
# Out:
# 2026-04-04 16:58:07.586640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775321887.801006      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775321887.861989      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775321888.352770      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775321888.352806      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775321888.352809      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775321888.352811      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Device: cuda
# Compute Capability: 7.5 (CC < 8.0 → mLSTM)
# USE_SLSTM: False
# Encoder output: torch.Size([2, 128])  (ожидается [2, 128])

# %% [markdown]
# ## Шаг 5: Обучение Short-модели

# %%
from stable_baselines3.common.vec_env import DummyVecEnv

BATCH_SIZE    = 32
TOTAL_STEPS   = 500_000
LEARNING_RATE = 3e-4

policy_kwargs = dict(
    features_extractor_class=xLSTMEncoder,
    features_extractor_kwargs=dict(
        embedding_dim=EMBEDDING_DIM, num_blocks=4, use_slstm=USE_SLSTM),
    lstm_hidden_size=128,
    n_lstm_layers=1,
    enable_critic_lstm=True,
    net_arch=[],
)

vec_env_short = DummyVecEnv([lambda: MOEXTradingEnvShort(
    close_prices=close_train, features=features_train,
    turbulence=turb_train_arr, turbulence_threshold=TURBULENCE_THRESHOLD,
    window_size=WINDOW_SIZE, margin_ratio=0.5,
)])

model_short = RecurrentPPO(
    policy='MlpLstmPolicy',
    env=vec_env_short,
    policy_kwargs=policy_kwargs,
    learning_rate=LEARNING_RATE,
    n_steps=2048,
    batch_size=BATCH_SIZE,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    vf_coef=0.5,
    max_grad_norm=0.5,
    verbose=1,
    seed=42,
    tensorboard_log='./tb_logs/',
    device=DEVICE,
)

print(f'Начинаем обучение: {TOTAL_STEPS:,} шагов...')
model_short.learn(total_timesteps=TOTAL_STEPS, progress_bar=True)
model_short.save('xlstm_ppo_moex_short')
print('Готово. Сохранено: xlstm_ppo_moex_short')
# Out:
# Using cuda device
# Начинаем обучение: 500,000 шагов...
# Logging to ./tb_logs/RecurrentPPO_1
# Output()
# -----------------------------
# | time/              |      |
# |    fps             | 110  |
# |    iterations      | 1    |
# |    time_elapsed    | 18   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 2           |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009114871 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.12       |
# |    explained_variance   | -0.00871    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00455    |
# |    std                  | 1.01        |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 3           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010407571 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.44        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00167    |
# |    std                  | 1.01        |
# |    value_loss           | 13.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 4           |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010081671 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.13       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00495    |
# |    std                  | 1.01        |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 59           |
# |    iterations           | 5            |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0131534245 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.14        |
# |    explained_variance   | 0.587        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0869       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00189     |
# |    std                  | 1.01         |
# |    value_loss           | 10.5         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 6          |
# |    time_elapsed         | 209        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01052051 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.16      |
# |    explained_variance   | 0.69       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.7       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00364   |
# |    std                  | 1.01       |
# |    value_loss           | 9.52       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 57        |
# |    iterations           | 7         |
# |    time_elapsed         | 247       |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0125218 |
# |    clip_fraction        | 0.144     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.16     |
# |    explained_variance   | 0.783     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0255   |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.00414  |
# |    std                  | 1.01      |
# |    value_loss           | 8.23      |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 57           |
# |    iterations           | 8            |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0111747775 |
# |    clip_fraction        | 0.14         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.19        |
# |    explained_variance   | 0.834        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.565        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00475     |
# |    std                  | 1.02         |
# |    value_loss           | 8.19         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 9          |
# |    time_elapsed         | 323        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01352535 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.19      |
# |    explained_variance   | 0.838      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.739      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00641   |
# |    std                  | 1.02       |
# |    value_loss           | 7.49       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 10         |
# |    time_elapsed         | 361        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01585089 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.21      |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.27       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 1.03       |
# |    value_loss           | 6.32       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 11          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.018580781 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.22       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 1.03        |
# |    value_loss           | 6.68        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 12          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016145073 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.26       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.597       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0092     |
# |    std                  | 1.04        |
# |    value_loss           | 5.75        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 13          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019280095 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.28       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 1.04        |
# |    value_loss           | 4.59        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 14          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.024185115 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.3        |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.881       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 1.04        |
# |    value_loss           | 3.99        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 15          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023904435 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.31       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0877      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1.04        |
# |    value_loss           | 2.89        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 16          |
# |    time_elapsed         | 591         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.030137572 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.32       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.22        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 1.05        |
# |    value_loss           | 2.06        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 17          |
# |    time_elapsed         | 629         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.044279385 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.34       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.191       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0294     |
# |    std                  | 1.05        |
# |    value_loss           | 1.88        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 18          |
# |    time_elapsed         | 666         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.043970063 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.32       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.114      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 1.05        |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 19          |
# |    time_elapsed         | 704         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.038918883 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.31       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.247       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0274     |
# |    std                  | 1.05        |
# |    value_loss           | 2.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 20          |
# |    time_elapsed         | 742         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.048323687 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.33       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 1.05        |
# |    value_loss           | 2.1         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 21          |
# |    time_elapsed         | 780         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.040322464 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.31       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0333     |
# |    std                  | 1.04        |
# |    value_loss           | 1.91        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 22          |
# |    time_elapsed         | 818         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.057016835 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.32       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.323       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0358     |
# |    std                  | 1.05        |
# |    value_loss           | 1.76        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 23          |
# |    time_elapsed         | 857         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.061968464 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.35       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.14       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0359     |
# |    std                  | 1.05        |
# |    value_loss           | 1.56        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 24         |
# |    time_elapsed         | 895        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.06489623 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.36      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.511      |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.041     |
# |    std                  | 1.05       |
# |    value_loss           | 1.25       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 25          |
# |    time_elapsed         | 934         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.077365786 |
# |    clip_fraction        | 0.434       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.36       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.154      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0454     |
# |    std                  | 1.05        |
# |    value_loss           | 1.14        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 26         |
# |    time_elapsed         | 972        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.09431633 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.37      |
# |    explained_variance   | 0.989      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.7       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0541    |
# |    std                  | 1.06       |
# |    value_loss           | 1.23       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 27         |
# |    time_elapsed         | 1010       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.10591945 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.37      |
# |    explained_variance   | 0.99       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.16       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0521    |
# |    std                  | 1.05       |
# |    value_loss           | 1.03       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 28          |
# |    time_elapsed         | 1049        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.111775756 |
# |    clip_fraction        | 0.482       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.37       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.577       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0491     |
# |    std                  | 1.06        |
# |    value_loss           | 1.37        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 29         |
# |    time_elapsed         | 1087       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.13854289 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.38      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0616    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0553    |
# |    std                  | 1.06       |
# |    value_loss           | 0.986      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 30         |
# |    time_elapsed         | 1125       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.12330279 |
# |    clip_fraction        | 0.506      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.42      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.142     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0598    |
# |    std                  | 1.07       |
# |    value_loss           | 0.838      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 31         |
# |    time_elapsed         | 1163       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.15755424 |
# |    clip_fraction        | 0.529      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.4       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.682      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0657    |
# |    std                  | 1.06       |
# |    value_loss           | 0.912      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 32         |
# |    time_elapsed         | 1201       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.14944413 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.39      |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0389    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0642    |
# |    std                  | 1.06       |
# |    value_loss           | 0.358      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 33         |
# |    time_elapsed         | 1239       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.17373618 |
# |    clip_fraction        | 0.561      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.4       |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.65       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0695    |
# |    std                  | 1.06       |
# |    value_loss           | 0.605      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 34         |
# |    time_elapsed         | 1277       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.17006415 |
# |    clip_fraction        | 0.569      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.38      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0475     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0761    |
# |    std                  | 1.06       |
# |    value_loss           | 0.462      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 35         |
# |    time_elapsed         | 1315       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.17875315 |
# |    clip_fraction        | 0.551      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.39      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.204     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0726    |
# |    std                  | 1.06       |
# |    value_loss           | 0.543      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 36         |
# |    time_elapsed         | 1353       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.16094568 |
# |    clip_fraction        | 0.565      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.39      |
# |    explained_variance   | 0.994      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.208     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0717    |
# |    std                  | 1.06       |
# |    value_loss           | 0.678      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 37         |
# |    time_elapsed         | 1391       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.20480907 |
# |    clip_fraction        | 0.571      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.38      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.194     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0788    |
# |    std                  | 1.06       |
# |    value_loss           | 0.451      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 38         |
# |    time_elapsed         | 1428       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.23837243 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.36      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.137     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0788    |
# |    std                  | 1.06       |
# |    value_loss           | 0.368      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 39         |
# |    time_elapsed         | 1466       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.23525795 |
# |    clip_fraction        | 0.611      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.38      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.143      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0781    |
# |    std                  | 1.06       |
# |    value_loss           | 0.317      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 40         |
# |    time_elapsed         | 1504       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.23660886 |
# |    clip_fraction        | 0.61       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.4       |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.11      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0835    |
# |    std                  | 1.06       |
# |    value_loss           | 0.443      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 41         |
# |    time_elapsed         | 1542       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.31489116 |
# |    clip_fraction        | 0.631      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.38      |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.183     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0881    |
# |    std                  | 1.06       |
# |    value_loss           | 0.471      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 42         |
# |    time_elapsed         | 1580       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.31782055 |
# |    clip_fraction        | 0.634      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.39      |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.195     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0785    |
# |    std                  | 1.06       |
# |    value_loss           | 0.355      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 43         |
# |    time_elapsed         | 1618       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.29334113 |
# |    clip_fraction        | 0.637      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.4       |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.122     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0808    |
# |    std                  | 1.06       |
# |    value_loss           | 0.324      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 44        |
# |    time_elapsed         | 1655      |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.2946931 |
# |    clip_fraction        | 0.644     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.4      |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.17     |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.0826   |
# |    std                  | 1.06      |
# |    value_loss           | 0.227     |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 45        |
# |    time_elapsed         | 1694      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.3079787 |
# |    clip_fraction        | 0.65      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.4      |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.165    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0878   |
# |    std                  | 1.06      |
# |    value_loss           | 0.232     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 46         |
# |    time_elapsed         | 1731       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.31923813 |
# |    clip_fraction        | 0.657      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.4       |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.208     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.089     |
# |    std                  | 1.06       |
# |    value_loss           | 0.196      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 47         |
# |    time_elapsed         | 1769       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.35173422 |
# |    clip_fraction        | 0.657      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.39      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.117     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0837    |
# |    std                  | 1.06       |
# |    value_loss           | 0.21       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 48         |
# |    time_elapsed         | 1807       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.37233502 |
# |    clip_fraction        | 0.669      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.42      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.17      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0821    |
# |    std                  | 1.07       |
# |    value_loss           | 0.152      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 49         |
# |    time_elapsed         | 1845       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.34764868 |
# |    clip_fraction        | 0.671      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.46      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.222     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0883    |
# |    std                  | 1.08       |
# |    value_loss           | 0.121      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 50         |
# |    time_elapsed         | 1883       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.34331614 |
# |    clip_fraction        | 0.678      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.48      |
# |    explained_variance   | 0.998      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.182     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0989    |
# |    std                  | 1.08       |
# |    value_loss           | 0.179      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 51         |
# |    time_elapsed         | 1921       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.32919833 |
# |    clip_fraction        | 0.666      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.5       |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.106     |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0925    |
# |    std                  | 1.09       |
# |    value_loss           | 0.165      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 53         |
# |    time_elapsed         | 1998       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.31437832 |
# |    clip_fraction        | 0.663      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.55      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.121     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0882    |
# |    std                  | 1.1        |
# |    value_loss           | 0.165      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 54         |
# |    time_elapsed         | 2037       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.34130335 |
# |    clip_fraction        | 0.674      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.57      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.128     |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0929    |
# |    std                  | 1.1        |
# |    value_loss           | 0.124      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 55         |
# |    time_elapsed         | 2075       |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.36006027 |
# |    clip_fraction        | 0.674      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.6       |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.214     |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0911    |
# |    std                  | 1.11       |
# |    value_loss           | 0.122      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 56        |
# |    time_elapsed         | 2114      |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.3391503 |
# |    clip_fraction        | 0.691     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.6      |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.241     |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -0.0956   |
# |    std                  | 1.11      |
# |    value_loss           | 0.128     |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 54       |
# |    iterations           | 57       |
# |    time_elapsed         | 2152     |
# |    total_timesteps      | 116736   |
# | train/                  |          |
# |    approx_kl            | 0.366417 |
# |    clip_fraction        | 0.677    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -7.63    |
# |    explained_variance   | 0.999    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.218   |
# |    n_updates            | 560      |
# |    policy_gradient_loss | -0.0906  |
# |    std                  | 1.12     |
# |    value_loss           | 0.121    |
# --------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 58        |
# |    time_elapsed         | 2191      |
# |    total_timesteps      | 118784    |
# | train/                  |           |
# |    approx_kl            | 0.3804744 |
# |    clip_fraction        | 0.687     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.66     |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.204    |
# |    n_updates            | 570       |
# |    policy_gradient_loss | -0.0898   |
# |    std                  | 1.12      |
# |    value_loss           | 0.171     |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 59        |
# |    time_elapsed         | 2229      |
# |    total_timesteps      | 120832    |
# | train/                  |           |
# |    approx_kl            | 0.4246775 |
# |    clip_fraction        | 0.706     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.69     |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0262   |
# |    n_updates            | 580       |
# |    policy_gradient_loss | -0.106    |
# |    std                  | 1.13      |
# |    value_loss           | 0.17      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 60         |
# |    time_elapsed         | 2269       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.39682132 |
# |    clip_fraction        | 0.694      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.75      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.166     |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0911    |
# |    std                  | 1.15       |
# |    value_loss           | 0.108      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 61         |
# |    time_elapsed         | 2309       |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.39339742 |
# |    clip_fraction        | 0.692      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.8       |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.232     |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0974    |
# |    std                  | 1.16       |
# |    value_loss           | 0.162      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 62        |
# |    time_elapsed         | 2350      |
# |    total_timesteps      | 126976    |
# | train/                  |           |
# |    approx_kl            | 0.4254637 |
# |    clip_fraction        | 0.692     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.83     |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.175    |
# |    n_updates            | 610       |
# |    policy_gradient_loss | -0.0944   |
# |    std                  | 1.16      |
# |    value_loss           | 0.103     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 63         |
# |    time_elapsed         | 2388       |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.41859442 |
# |    clip_fraction        | 0.71       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.85      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.166     |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0984    |
# |    std                  | 1.17       |
# ...
# |    entropy_loss         | -13.8      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.293     |
# |    n_updates            | 2230       |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 3.89       |
# |    value_loss           | 0.0342     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 225        |
# |    time_elapsed         | 8514       |
# |    total_timesteps      | 460800     |
# | train/                  |            |
# |    approx_kl            | 0.37095654 |
# |    clip_fraction        | 0.72       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.9      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.252     |
# |    n_updates            | 2240       |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 3.92       |
# |    value_loss           | 0.0192     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 226       |
# |    time_elapsed         | 8551      |
# |    total_timesteps      | 462848    |
# | train/                  |           |
# |    approx_kl            | 0.3647189 |
# |    clip_fraction        | 0.719     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -13.9     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.126    |
# |    n_updates            | 2250      |
# |    policy_gradient_loss | -0.114    |
# |    std                  | 3.95      |
# |    value_loss           | 0.0196    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 227        |
# |    time_elapsed         | 8589       |
# |    total_timesteps      | 464896     |
# | train/                  |            |
# |    approx_kl            | 0.38813326 |
# |    clip_fraction        | 0.732      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14        |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.3       |
# |    n_updates            | 2260       |
# |    policy_gradient_loss | -0.112     |
# |    std                  | 3.98       |
# |    value_loss           | 0.0197     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 228        |
# |    time_elapsed         | 8626       |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.40200078 |
# |    clip_fraction        | 0.719      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14        |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.298     |
# |    n_updates            | 2270       |
# |    policy_gradient_loss | -0.112     |
# |    std                  | 4.03       |
# |    value_loss           | 0.0296     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 229        |
# |    time_elapsed         | 8664       |
# |    total_timesteps      | 468992     |
# | train/                  |            |
# |    approx_kl            | 0.38272887 |
# |    clip_fraction        | 0.718      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.1      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.268     |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 4.08       |
# |    value_loss           | 0.0249     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 230        |
# |    time_elapsed         | 8702       |
# |    total_timesteps      | 471040     |
# | train/                  |            |
# |    approx_kl            | 0.35171568 |
# |    clip_fraction        | 0.721      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.1      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.291     |
# |    n_updates            | 2290       |
# |    policy_gradient_loss | -0.108     |
# |    std                  | 4.12       |
# |    value_loss           | 0.0223     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 231       |
# |    time_elapsed         | 8739      |
# |    total_timesteps      | 473088    |
# | train/                  |           |
# |    approx_kl            | 0.3392437 |
# |    clip_fraction        | 0.728     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.2     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.27     |
# |    n_updates            | 2300      |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 4.13      |
# |    value_loss           | 0.0129    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 232        |
# |    time_elapsed         | 8778       |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.37304875 |
# |    clip_fraction        | 0.721      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.2      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.283     |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | -0.114     |
# |    std                  | 4.17       |
# |    value_loss           | 0.0527     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 234        |
# |    time_elapsed         | 8855       |
# |    total_timesteps      | 479232     |
# | train/                  |            |
# |    approx_kl            | 0.37121046 |
# |    clip_fraction        | 0.722      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.3      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.289     |
# |    n_updates            | 2330       |
# |    policy_gradient_loss | -0.109     |
# |    std                  | 4.22       |
# |    value_loss           | 0.0301     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 235       |
# |    time_elapsed         | 8892      |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 0.3309296 |
# |    clip_fraction        | 0.717     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.3     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.258    |
# |    n_updates            | 2340      |
# |    policy_gradient_loss | -0.108    |
# |    std                  | 4.25      |
# |    value_loss           | 0.0172    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 236        |
# |    time_elapsed         | 8930       |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.31290692 |
# |    clip_fraction        | 0.719      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.3      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.276     |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | -0.114     |
# |    std                  | 4.28       |
# |    value_loss           | 0.0157     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 237       |
# |    time_elapsed         | 8968      |
# |    total_timesteps      | 485376    |
# | train/                  |           |
# |    approx_kl            | 0.3428725 |
# |    clip_fraction        | 0.725     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.4     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.292    |
# |    n_updates            | 2360      |
# |    policy_gradient_loss | -0.115    |
# |    std                  | 4.31      |
# |    value_loss           | 0.0145    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 238        |
# |    time_elapsed         | 9006       |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.33328462 |
# |    clip_fraction        | 0.725      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.4      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.281     |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.113     |
# |    std                  | 4.34       |
# |    value_loss           | 0.0202     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 239        |
# |    time_elapsed         | 9044       |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.30242488 |
# |    clip_fraction        | 0.714      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.4      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.267     |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 4.37       |
# |    value_loss           | 0.0157     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 240       |
# |    time_elapsed         | 9082      |
# |    total_timesteps      | 491520    |
# | train/                  |           |
# |    approx_kl            | 0.4313782 |
# |    clip_fraction        | 0.729     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.5     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.298    |
# |    n_updates            | 2390      |
# |    policy_gradient_loss | -0.115    |
# |    std                  | 4.39      |
# |    value_loss           | 0.016     |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 241       |
# |    time_elapsed         | 9119      |
# |    total_timesteps      | 493568    |
# | train/                  |           |
# |    approx_kl            | 0.3613015 |
# |    clip_fraction        | 0.72      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.5     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.285    |
# |    n_updates            | 2400      |
# |    policy_gradient_loss | -0.11     |
# |    std                  | 4.43      |
# |    value_loss           | 0.0294    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 242       |
# |    time_elapsed         | 9157      |
# |    total_timesteps      | 495616    |
# | train/                  |           |
# |    approx_kl            | 0.3534637 |
# |    clip_fraction        | 0.723     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.5     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.285    |
# |    n_updates            | 2410      |
# |    policy_gradient_loss | -0.115    |
# |    std                  | 4.45      |
# |    value_loss           | 0.0496    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 243        |
# |    time_elapsed         | 9195       |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.35362855 |
# |    clip_fraction        | 0.721      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.6      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.311     |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.112     |
# |    std                  | 4.51       |
# |    value_loss           | 0.0475     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 54        |
# |    iterations           | 244       |
# |    time_elapsed         | 9233      |
# |    total_timesteps      | 499712    |
# | train/                  |           |
# |    approx_kl            | 0.3527609 |
# |    clip_fraction        | 0.728     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.6     |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.297    |
# |    n_updates            | 2430      |
# |    policy_gradient_loss | -0.111    |
# |    std                  | 4.54      |
# |    value_loss           | 0.0377    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 245        |
# |    time_elapsed         | 9271       |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.32436442 |
# |    clip_fraction        | 0.722      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.7      |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.262     |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.112     |
# |    std                  | 4.59       |
# |    value_loss           | 0.0671     |
# ----------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Готово. Сохранено: xlstm_ppo_moex_short

# %% [markdown]
# ## Шаг 6: Тестирование + метрики

# %%
def run_episode(model, env):
    obs, _         = env.reset()
    obs            = obs[np.newaxis, ...]
    lstm_states    = None
    episode_starts = np.array([True])
    done           = False
    while not done:
        action, lstm_states = model.predict(
            obs, state=lstm_states,
            episode_start=episode_starts, deterministic=True)
        obs_raw, _, terminated, truncated, _ = env.step(action[0])
        obs            = obs_raw[np.newaxis, ...]
        episode_starts = np.array([terminated or truncated])
        done           = terminated or truncated
    return env.portfolio_history


def compute_metrics(portfolio_history, initial_balance, n_trades, risk_free_rate=0.16):
    values  = np.array(portfolio_history, dtype=float)
    P_init  = initial_balance
    P_final = values[-1]
    CR   = (P_final - P_init) / P_init * 100
    MER  = (values.max() - P_init) / P_init * 100
    rmax = np.maximum.accumulate(values)
    MPB  = abs(((values - rmax) / (rmax + 1e-8)).min()) * 100
    APPT = (P_final - P_init) / max(n_trades, 1) / 1000
    dr   = np.diff(values) / (values[:-1] + 1e-8)
    ex   = dr - risk_free_rate / 252
    SR   = (ex.mean() / (ex.std() + 1e-8)) * np.sqrt(252)
    return {'CR': CR, 'MER': MER, 'MPB': MPB, 'APPT': APPT, 'SR': SR}


# Загружаем модель
model_short_loaded = RecurrentPPO.load(
    'xlstm_ppo_moex_short',
    env=DummyVecEnv([lambda: MOEXTradingEnvShort(
        close_prices=close_test, features=features_test,
        turbulence=turb_test_arr, turbulence_threshold=TURBULENCE_THRESHOLD,
        window_size=WINDOW_SIZE, margin_ratio=0.5,
    )])
)

print('=== ТЕСТИРОВАНИЕ SHORT МОДЕЛИ (2022–2024) ===')
portfolio_hist_short = run_episode(model_short_loaded, env_test_short)

print(f'Минимальное shares_held: {env_test_short.shares_held.min():.4f}')
print(f'Есть шорты: {(env_test_short.shares_held < 0).any()}')

short_metrics = compute_metrics(
    portfolio_hist_short,
    initial_balance=env_test_short.initial_balance,
    n_trades=env_test_short.trade_count,
)

print(f"""
┌─────────────────────────────────────────────────┐
│       РЕЗУЛЬТАТЫ SHORT МОДЕЛИ (MOEX)            │
├────────────────────────────┬────────────────────┤
│ Cumulative Return (CR)     │ {short_metrics['CR']:>+.2f}%            │
│ Max Earning Rate (MER)     │ {short_metrics['MER']:>+.2f}%            │
│ Max PullBack (MPB)         │ {short_metrics['MPB']:>.2f}%             │
│ Avg Profit/Trade (APPT)    │ {short_metrics['APPT']:>.2f}k ₽          │
│ Sharpe Ratio (SR)          │ {short_metrics['SR']:>.3f}             │
│ Всего сделок               │ {env_test_short.trade_count:<20} │
└────────────────────────────┴────────────────────┘
""")
# Out:
# === ТЕСТИРОВАНИЕ SHORT МОДЕЛИ (2022–2024) ===
# Минимальное shares_held: -1972.9669
# Есть шорты: True
#
# ┌─────────────────────────────────────────────────┐
# │       РЕЗУЛЬТАТЫ SHORT МОДЕЛИ (MOEX)            │
# ├────────────────────────────┬────────────────────┤
# │ Cumulative Return (CR)     │ -33.76%            │
# │ Max Earning Rate (MER)     │ +64.01%            │
# │ Max PullBack (MPB)         │ 72.89%             │
# │ Avg Profit/Trade (APPT)    │ -0.90k ₽          │
# │ Sharpe Ratio (SR)          │ -0.220             │
# │ Всего сделок               │ 375                  │
# └────────────────────────────┴────────────────────┘

# %% [markdown]
# ## Шаг 7: Визуализация

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

portfolio_short = np.array(portfolio_hist_short)
days            = np.arange(len(portfolio_short))
returns_pct     = (portfolio_short / env_test_short.initial_balance - 1) * 100
daily_rets      = np.diff(portfolio_short) / portfolio_short[:-1] * 100

fig, axes = plt.subplots(3, 1, figsize=(14, 10), sharex=False)
fig.suptitle('xLSTM + Recurrent PPO (Short) — MOEX (тест 2022–2024)',
             fontsize=14, fontweight='bold', y=0.98)

ax = axes[0]
ax.plot(days, portfolio_short / 1e6, color='steelblue', linewidth=1.5, label='Портфель')
ax.axhline(y=env_test_short.initial_balance / 1e6, color='gray',
           linestyle='--', linewidth=1, label='Начальный капитал')
ax.set_ylabel('Стоимость (млн ₽)')
ax.set_title('Динамика портфеля')
ax.legend(); ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(days, returns_pct, color='seagreen', linewidth=1.5)
ax.axhline(y=0, color='black', linewidth=0.8)
ax.fill_between(days, returns_pct, 0, where=(returns_pct >= 0), alpha=0.2, color='seagreen')
ax.fill_between(days, returns_pct, 0, where=(returns_pct < 0),  alpha=0.2, color='tomato')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('Доходность (%)'); ax.set_title('Накопленная доходность'); ax.grid(True, alpha=0.3)

ax = axes[2]
colors_bar = ['seagreen' if r >= 0 else 'tomato' for r in daily_rets]
ax.bar(np.arange(len(daily_rets)), daily_rets, color=colors_bar, alpha=0.7, width=1.0)
ax.axhline(y=0, color='black', linewidth=0.8)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_xlabel('Торговый день'); ax.set_ylabel('Дневная доходность (%)'); ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('moex_xlstm_short_results.png', dpi=150, bbox_inches='tight')
plt.show()
print('График сохранён: moex_xlstm_short_results.png')
# Out:
# График сохранён: moex_xlstm_short_results.png

# %% [markdown]
# ## Шаг 8: LSTM baseline (short) для сравнения

# %%
class LSTMEncoder(BaseFeaturesExtractor):
    def __init__(self, observation_space, hidden_dim=128):
        super().__init__(observation_space, features_dim=hidden_dim)
        _, n_features = observation_space.shape
        self.lstm = nn.LSTM(input_size=n_features, hidden_size=hidden_dim,
                            num_layers=1, batch_first=True)
    def forward(self, obs):
        out, _ = self.lstm(obs)
        return out[:, -1, :]


vec_env_baseline = DummyVecEnv([lambda: MOEXTradingEnvShort(
    close_prices=close_train, features=features_train,
    turbulence=turb_train_arr, turbulence_threshold=TURBULENCE_THRESHOLD,
    window_size=WINDOW_SIZE, margin_ratio=0.5,
)])

baseline_model = RecurrentPPO(
    policy='MlpLstmPolicy',
    env=vec_env_baseline,
    policy_kwargs=dict(
        features_extractor_class=LSTMEncoder,
        features_extractor_kwargs=dict(hidden_dim=128),
        lstm_hidden_size=128, n_lstm_layers=1,
        enable_critic_lstm=True, net_arch=[]),
    learning_rate=LEARNING_RATE,
    n_steps=2048,
    batch_size=BATCH_SIZE,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    ent_coef=0.01,
    vf_coef=0.5,
    max_grad_norm=0.5,
    verbose=1,
    seed=42,
    device=DEVICE,
)

print('Обучаем LSTM baseline (short)...')
baseline_model.learn(total_timesteps=TOTAL_STEPS, progress_bar=True)
baseline_model.save('lstm_baseline_moex_short')

env_test_baseline = MOEXTradingEnvShort(
    close_prices=close_test, features=features_test,
    turbulence=turb_test_arr, turbulence_threshold=TURBULENCE_THRESHOLD,
    window_size=WINDOW_SIZE, margin_ratio=0.5)

baseline_hist    = run_episode(baseline_model, env_test_baseline)
baseline_metrics = compute_metrics(
    baseline_hist, env_test_baseline.initial_balance, env_test_baseline.trade_count)

print('\n' + '='*58)
print(f"{'Метрика':<10} {'LSTM+Short':>14} {'xLSTM+Short':>14}")
print('-'*58)
for k in ['CR', 'MER', 'MPB', 'APPT', 'SR']:
    print(f"{k:<10} {baseline_metrics[k]:>14.3f} {short_metrics[k]:>14.3f}")
print('='*58)
